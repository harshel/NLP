# %%
import os

# %%
with open(os.path.join('data/hieroglyph.txt'), 'r') as f:
    text = f.read()

# %%
print(text)
# Out:
# Hieroglyphic writing dates from c. 3000 BC, and is composed of hundreds of symbols. A hieroglyph can represent a word, a sound, or a silent determinative; and the same symbol can serve different purposes in different contexts. Hieroglyphs were a formal script, used on stone monuments and in tombs, that could be as detailed as individual works of art.

# %%
with open(os.path.join('data', 'hieroglyph.txt'), 'r') as f:
    text1 = f.read()

# %%
print(text1)
# Out:
# Hieroglyphic writing dates from c. 3000 BC, and is composed of hundreds of symbols. A hieroglyph can represent a word, a sound, or a silent determinative; and the same symbol can serve different purposes in different contexts. Hieroglyphs were a formal script, used on stone monuments and in tombs, that could be as detailed as individual works of art.

# %%
import pandas as pd

# %%
df = pd.read_csv(os.path.join('data', 'news.csv'))

# %%
df1 = pd.read_csv(os.path.join('data/news.csv'))

# %%
df1.head()
# Out:
#    id                                              title  \
# 0   2  Fed's Charles Plosser sees high bar for change...
# 1   3  US open: Stocks fall after Fed official hints ...
# 2   4  Fed risks falling 'behind the curve', Charles ...
# 3   5  Fed's Plosser: Nasty Weather Has Curbed Job Gr...
# 4   6  Plosser: Fed May Have to Accelerate Tapering Pace
#
#                                                  url     publisher category  \
# 0  http://www.livemint.com/Politics/H2EvwJSK2VE6O...      Livemint        b
# 1  http://www.ifamagazine.com/news/us-open-stocks...  IFA Magazine        b
# 2  http://www.ifamagazine.com/news/fed-risks-fall...  IFA Magazine        b
# 3  http://www.moneynews.com/Economy/federal-reser...     Moneynews        b
# 4  http://www.nasdaq.com/article/plosser-fed-may-...        NASDAQ        b
#
#                            story             hostname      timestamp
# 0  ddUyU0VZz0BRneMioxUPQVP6sIxvM     www.livemint.com  1394470371207
# ...

# %%
print(df1.head()['title'])
# Out:
# 0    Fed's Charles Plosser sees high bar for change...
# 1    US open: Stocks fall after Fed official hints ...
# 2    Fed risks falling 'behind the curve', Charles ...
# 3    Fed's Plosser: Nasty Weather Has Curbed Job Gr...
# 4    Plosser: Fed May Have to Accelerate Tapering Pace
# Name: title, dtype: object

# %%
string = ['title', 'publisher']
for string_ in string:
    df[string_] = df[string_].str.lower()

# %%
df.head()
# Out:
#    id                                              title  \
# 0   2  fed's charles plosser sees high bar for change...
# 1   3  us open: stocks fall after fed official hints ...
# 2   4  fed risks falling 'behind the curve', charles ...
# 3   5  fed's plosser: nasty weather has curbed job gr...
# 4   6  plosser: fed may have to accelerate tapering pace
#
#                                                  url     publisher category  \
# 0  http://www.livemint.com/Politics/H2EvwJSK2VE6O...      livemint        b
# 1  http://www.ifamagazine.com/news/us-open-stocks...  ifa magazine        b
# 2  http://www.ifamagazine.com/news/fed-risks-fall...  ifa magazine        b
# 3  http://www.moneynews.com/Economy/federal-reser...     moneynews        b
# 4  http://www.nasdaq.com/article/plosser-fed-may-...        nasdaq        b
#
#                            story             hostname      timestamp
# 0  ddUyU0VZz0BRneMioxUPQVP6sIxvM     www.livemint.com  1394470371207
# ...

# %%
import requests

# Fetch a web page
r = requests.get("https://news.ycombinator.com")
print(r.text)
# Out:
# <html op="news"><head><meta name="referrer" content="origin"><meta name="viewport" content="width=device-width, initial-scale=1.0"><link rel="stylesheet" type="text/css" href="news.css?wmTEMTwhH9wYaZekfcVS">
#             <link rel="shortcut icon" href="favicon.ico">
#           <link rel="alternate" type="application/rss+xml" title="RSS" href="rss">
#         <title>Hacker News</title></head><body><center><table id="hnmain" border="0" cellpadding="0" cellspacing="0" width="85%" bgcolor="#f6f6ef">
#         <tr><td bgcolor="#ff6600"><table border="0" cellpadding="0" cellspacing="0" width="100%" style="padding:2px"><tr><td style="width:18px;padding-right:4px"><a href="https://news.ycombinator.com"><img src="y18.gif" width="18" height="18" style="border:1px white solid;"></a></td>
#                   <td style="line-height:12pt; height:10px;"><span class="pagetop"><b class="hnname"><a href="news">Hacker News</a></b>
# ...

# %%
import requests

# %%
r1 = requests.get('https://www.youtube.com/watch?v=SsFxy2bxpZU&index=3&list=PL7zYW7FHOfhgfFnfWXSFecQLU5bhUOR5j')
print(r1.text)
# Out:
# <!DOCTYPE html><html lang="en" data-cast-api-enabled="true"><head><style name="www-roboto" >@font-face{font-family:'Roboto';font-style:normal;font-weight:400;src:local('Roboto Regular'),local('Roboto-Regular'),url(//fonts.gstatic.com/s/roboto/v18/KFOmCnqEu92Fr1Mu4mxP.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:italic;font-weight:400;src:local('Roboto Italic'),local('Roboto-Italic'),url(//fonts.gstatic.com/s/roboto/v18/KFOkCnqEu92Fr1Mu51xIIzc.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:italic;font-weight:500;src:local('Roboto Medium Italic'),local('Roboto-MediumItalic'),url(//fonts.gstatic.com/s/roboto/v18/KFOjCnqEu92Fr1Mu51S7ACc6CsE.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:500;src:local('Roboto Medium'),local('Roboto-Medium'),url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmEU9fBBc9.ttf)format('truetype');}</style><script name="www-roboto" >if (document.fonts && document.fonts.load) {docume
# ...

# %%
text = "The first time you see The Second Renaissance it may look boring. Look at it at least twice and definitely watch part 2. It will change your view of the matrix. Are the human people the ones who started the war ? Is AI a bad thing ?"
print(text)
# Out:
# The first time you see The Second Renaissance it may look boring. Look at it at least twice and definitely watch part 2. It will change your view of the matrix. Are the human people the ones who started the war ? Is AI a bad thing ?

# %%
text = text.lower()
print(text)
# Out:
# the first time you see the second renaissance it may look boring. look at it at least twice and definitely watch part 2. it will change your view of the matrix. are the human people the ones who started the war ? is ai a bad thing ?

# %%
#removing the punctuations
import re

# %%
text = re.sub("[^a-zA-Z0-9]", " ", text)

# %%
print(text)
# Out:
# the first time you see the second renaissance it may look boring  look at it at least twice and definitely watch part 2  it will change your view of the matrix  are the human people the ones who started the war   is ai a bad thing

# %%
import re
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize

# %%
text = "Dr. Smith graduated from the University of Washington!!. He, later started an analytics firm called Lux, which catered to enterprise customers. Wow!!!"
print(text)
# Out:
# Dr. Smith graduated from the University of Washington!!. He, later started an analytics firm called Lux, which catered to enterprise customers. Wow!!!

# %%
words = word_tokenize(text)
print(words)
# Out:
# ['Dr.', 'Smith', 'graduated', 'from', 'the', 'University', 'of', 'Washington', '!', '!', '.', 'He', ',', 'later', 'started', 'an', 'analytics', 'firm', 'called', 'Lux', ',', 'which', 'catered', 'to', 'enterprise', 'customers', '.', 'Wow', '!', '!', '!']

# %%
print(sent_tokenize(text))
# Out:
# ['Dr. Smith graduated from the University of Washington!!.', 'He, later started an analytics firm called Lux, which catered to enterprise customers.', 'Wow!!', '!']

# %%
text = re.sub(r"[^a-zA-Z0-9]", " ", text.lower())

# %%
print(text)
# Out:
# dr  smith graduated from the university of washington    he  later started an analytics firm called lux  which catered to enterprise customers  wow

# %%
words = word_tokenize(text)

# %%
print(len(words))
# Out:
# 22

# %%
from nltk.corpus import stopwords

# %%
stop = [w for w in words if w not in stopwords.words('english')]

# %%
print(stop)
# Out:
# ['dr', 'smith', 'graduated', 'university', 'washington', 'later', 'started', 'analytics', 'firm', 'called', 'lux', 'catered', 'enterprise', 'customers', 'wow']

# %%
print(len(stop))
# Out:
# 15

# %%
import nltk

# Define a custom grammar
my_grammar = nltk.CFG.fromstring("""
S -> NP VP
PP -> P NP
NP -> Det N | Det N PP | 'I'
VP -> V NP | VP PP
Det -> 'an' | 'my'
N -> 'elephant' | 'pajamas'
V -> 'shot'
P -> 'in'
""")
parser = nltk.ChartParser(my_grammar)

# Parse a sentence
sentence = word_tokenize("I shot an elephant in my pajamas")
for tree in parser.parse(sentence):
    print(tree)
# Out:
# (S
#   (NP I)
#   (VP
#     (VP (V shot) (NP (Det an) (N elephant)))
#     (PP (P in) (NP (Det my) (N pajamas)))))
# (S
#   (NP I)
#   (VP
#     (V shot)
#     (NP (Det an) (N elephant) (PP (P in) (NP (Det my) (N pajamas))))))

# %%
from nltk.stem import PorterStemmer

# %%
stem = PorterStemmer()

# %%
[stem.stem(w) for w in stop]
# Out:
# ['dr',
#  'smith',
#  'graduat',
#  'univers',
#  'washington',
#  'later',
#  'start',
#  'analyt',
#  'firm',
#  'call',
#  'lux',
#  'cater',
#  'enterpris',
#  'custom',
#  'wow']

# %%
from nltk.stem import WordNetLemmatizer

# %%
lemma = WordNetLemmatizer()

# %%
[lemma.lemmatize(w) for w in stop]
# Out:
# ['dr',
#  'smith',
#  'graduated',
#  'university',
#  'washington',
#  'later',
#  'started',
#  'analytics',
#  'firm',
#  'called',
#  'lux',
#  'catered',
#  'enterprise',
#  'customer',
#  'wow']

# %%
words_1 = ['starting', 'finishing', 'playing', 'walking', 'sleeping', 'crying', 'played', 'cleaned']

# %%
[WordNetLemmatizer().lemmatize(w) for w in words_1]
# Out:
# ['starting',
#  'finishing',
#  'playing',
#  'walking',
#  'sleeping',
#  'cry',
#  'played',
#  'cleaned']

# %%
[PorterStemmer().stem(w) for w in words_1]
# Out:
# ['start', 'finish', 'play', 'walk', 'sleep', 'cri', 'play', 'clean']

# %%
import gensim
from nltk.tokenize import word_tokenize
# Out:
# C:\Users\Harshal\Anaconda3\lib\site-packages\gensim\utils.py:1212: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
sentences = [['This is the first sentence of the vocab.'],
           ['damn, this is a second sentence.'],
           ['what about the third sentence.'],
           ['here comes the fourth']]

# %%
tokens = [[[w for w in word_tokenize(sent1)] for sent1 in sentences[i]] for i in range(len(sentences))]

# %%
len(tokens)
# Out:
# 4

# %%
tokens1 = []
for i in range(len(tokens)):
    for token in tokens[i]:
        tokens1.append(token)

# %%
tokens1
# Out:
# [['This', 'is', 'the', 'first', 'sentence', 'of', 'the', 'vocab', '.'],
#  ['damn', ',', 'this', 'is', 'a', 'second', 'sentence', '.'],
#  ['what', 'about', 'the', 'third', 'sentence', '.'],
#  ['here', 'comes', 'the', 'fourth']]

# %%
from gensim.models import Word2Vec

# %%
word2vec = Word2Vec(tokens1, min_count = 1)

# %%
print(word2vec)
# Out:
# Word2Vec(vocab=19, size=100, alpha=0.025)

# %%
words = list(word2vec.wv.vocab)

# %%
print(words)
# Out:
# ['This', 'is', 'the', 'first', 'sentence', 'of', 'vocab', '.', 'damn', ',', 'this', 'a', 'second', 'what', 'about', 'third', 'here', 'comes', 'fourth']

# %%
print(word2vec['damn'])
# Out:
# [-1.7744444e-03  1.1426606e-03 -5.5049860e-04  6.8916107e-04
#  -3.8045493e-03  3.5941310e-03  3.2930637e-03  2.5280388e-03
#  -4.7042328e-03 -2.7905258e-03 -4.8014703e-03  3.7498416e-03
#  -4.8375526e-03  4.3021482e-03 -3.2889523e-04  4.3154205e-03
#   2.1086209e-03  4.8607597e-03  2.9812783e-03  2.6771997e-03
#  -2.9335811e-03 -4.1471641e-03 -3.5021123e-03  4.1201701e-03
#   2.8312500e-03  1.7990005e-03  2.5456562e-03 -1.9104688e-03
#  -7.5518590e-04  2.9502134e-04  2.5521650e-03  3.1573512e-04
#   1.6664625e-03 -2.0294536e-03  2.8682780e-03  4.7785859e-03
#   1.6492846e-03 -1.9845719e-04  3.7270593e-03  9.4154367e-04
#  -3.4699584e-03 -4.3284744e-03  4.5582739e-04 -1.7251332e-03
#   3.2553729e-04  3.9653243e-03  2.8954516e-03 -1.0811737e-03
#  -2.0017640e-03  3.6225985e-03 -3.8217860e-03 -3.2818927e-03
#  -3.2519351e-03  1.2924420e-03 -2.5471621e-03  1.5614044e-03
#   3.4786831e-04  3.6009834e-03 -2.9505905e-05  3.2293599e-03
# ...

# %%
x = word2vec[word2vec.wv.vocab]
# Out:
# C:\Users\Harshal\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """Entry point for launching an IPython kernel.

# %%
print(x)
# Out:
# [[-0.00295133  0.00134532 -0.00045251 ...  0.0012629  -0.00470407
#   -0.00097225]
#  [ 0.00247741  0.00233368 -0.00022275 ...  0.00266977  0.00383706
#   -0.00245626]
#  [-0.00396649  0.00421987  0.00178125 ...  0.00428129  0.00219433
#   -0.00368133]
#  ...
#  [ 0.00018093 -0.0035569   0.00235697 ... -0.00338884 -0.00485086
#    0.00134518]
#  [ 0.00389739 -0.00012883  0.00018659 ... -0.00279092 -0.00226307
#    0.0030123 ]
#  [ 0.00292029 -0.00107082 -0.00116437 ... -0.00150577 -0.00449267
#   -0.00426531]]

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components = 2)

# %%
result = pca.fit_transform(x)

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(result[:,0], result[:,1])
words = list(word2vec.wv.vocab)
for i, word in enumerate(words):
    plt.annotate(word, xy = (result[i,0], result[i,1]))
plt.show()

# %%
print(list((word2vec.wv.vocab)))
# Out:
# ['This', 'is', 'the', 'first', 'sentence', 'of', 'vocab', '.', 'damn', ',', 'this', 'a', 'second', 'what', 'about', 'third', 'here', 'comes', 'fourth']
