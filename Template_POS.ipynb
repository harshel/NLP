# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('D:/farzad/Artificial Intelligence/Sem2/NLP/Consumer_Complaints.csv')

# %%
df = df[["Consumer complaint narrative", "Product"]]

# %%
df.dropna(inplace=True)

# %%
df["Consumer complaint narrative"] = df["Consumer complaint narrative"].str.lower()

# %%
list_of_sents = df["Consumer complaint narrative"][:5].tolist()

# %%
from nltk.tokenize import word_tokenize
BoW = [word_tokenize(x) for x in list_of_sents]

# %%
BoW = [item for sublist in BoW for item in sublist]

# %%
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from string import punctuation
from nltk.tokenize import word_tokenize
from textblob import TextBlob as tb

# %%
custom = list(set(stopwords.words('english')))+list(punctuation)+['``', "'s", "...", "n't"]

# %%
bow = [x for x in BoW if x not in custom]

# %%
bow = " ".join(bow)

# %%
blob = tb(bow)

# %%
blob.tags
# Out:
# [('outdated', 'VBN'),
#  ('information', 'NN'),
#  ('credit', 'NN'),
#  ('report', 'NN'),
#  ('previously', 'RB'),
#  ('disputed', 'VBN'),
#  ('yet', 'RB'),
#  ('removed', 'VBN'),
#  ('information', 'NN'),
#  ('seven', 'CD'),
#  ('years', 'NNS'),
#  ('old', 'JJ'),
#  ('meet', 'NN'),
#  ('credit', 'NN'),
#  ('reporting', 'NN'),
#  ('requirements', 'NNS'),
#  ('purchased', 'VBD'),
#  ('new', 'JJ'),
#  ('car', 'NN'),
#  ('xxxx', 'NN'),
#  ('xxxx', 'NN'),
#  ('car', 'NN'),
#  ('dealer', 'NN'),
#  ('called', 'VBD'),
#  ('citizens', 'NNS'),
#  ('bank', 'NN'),
#  ('get', 'VBP'),
#  ('10', 'CD'),
#  ('day', 'NN'),
#  ('payoff', 'NN'),
#  ('loan', 'NN'),
#  ('good', 'JJ'),
#  ('till', 'NN'),
#  ('xxxx', 'NNP'),
#  ('xxxx', 'NNP'),
#  ('dealer', 'NN'),
#  ('sent', 'VBD'),
#  ('check', 'NN'),
#  ('next', 'JJ'),
#  ('day', 'NN'),
#  ('balanced', 'VBD'),
#  ('checkbook', 'NN'),
#  ('xxxx', 'NNP'),
#  ('xxxx', 'NNP'),
#  ('noticed', 'VBD'),
#  ('citizens', 'NNS'),
#  ('bank', 'NN'),
#  ('taken', 'VBN'),
#  ('automatic', 'JJ'),
#  ('payment', 'NN'),
#  ('checking', 'VBG'),
#  ('account', 'NN'),
#  ('xxxx', 'NNP'),
#  ('xxxx', 'NNP'),
#  ('xxxx', 'NNP'),
#  ('bank', 'NN'),
#  ('called', 'VBD'),
#  ('citizens', 'NNS'),
#  ('stated', 'VBN'),
#  ('close', 'JJ'),
#  ('loan', 'NN'),
#  ('xxxx', 'NNP'),
#  ('xxxx', 'NNP'),
#  ('stating', 'VBG'),
#  ('receive', 'JJ'),
#  ('check', 'NN'),
#  ('xxxx', 'NNP'),
#  ('xxxx', 'NNP'),
#  ('told', 'VBD'),
#  ('believe', 'VBP'),
#  ('check', 'NN'),
#  ('took', 'VBD'),
#  ('long', 'RB'),
#  ('arrive', 'JJ'),
#  ('xxxx', 'NN'),
#  ('told', 'VBD'),
#  ('check', 'NN'),
#  ('issued', 'VBD'),
#  ('amount', 'NN'),
#  ('overpaid', 'RB'),
#  ('deducted', 'VBN'),
#  ('additional', 'JJ'),
#  ('interest', 'NN'),
#  ('today', 'NN'),
#  ('xxxx', 'NNP'),
#  ('xxxx', 'NNP'),
#  ('called', 'VBD'),
#  ('citizens', 'NNS'),
#  ('bank', 'NN'),
#  ('talked', 'VBD'),
#  ('supervisor', 'NN'),
#  ('named', 'VBN'),
#  ('xxxx', 'NNP'),
#  ('xxxx', 'NNP'),
#  ('xxxx', 'NNP'),
#  ('received', 'VBD'),
#  ('letter', 'NN'),
#  ('loan', 'NN'),
#  ('paid', 'VBN'),
#  ('full', 'JJ'),
#  ('dated', 'VBN'),
#  ('xxxx', 'JJ'),
#  ('xxxx', 'NNP'),
#  ('refund', 'NN'),
#  ('check', 'NN'),
#  ('included', 'VBD'),
#  ('xxxx', 'NNP'),
#  ('stated', 'VBD'),
#  ('hold', 'JJ'),
#  ('payment', 'NN'),
#  ('10', 'CD'),
#  ('business', 'NN'),
#  ('days', 'NNS'),
#  ('loan', 'NN'),
#  ('satisfied', 'VBD'),
#  ('check', 'NN'),
#  ('would', 'MD'),
#  ('mailed', 'VB'),
#  ('wed.', 'NN'),
#  ('xx/xx/xxxx..', 'NN'),
#  ('questioned', 'VBD'),
#  ('delay', 'RP'),
#  ('posting', 'VBG'),
#  ('dealer', 'NN'),
#  ('payment', 'NN'),
#  ('first', 'RB'),
#  ('stated', 'VBN'),
#  ('sometimes', 'RB'),
#  ('takes', 'VBZ'),
#  ('3', 'CD'),
#  ('4', 'CD'),
#  ('business', 'NN'),
#  ('days', 'NNS'),
#  ('post', 'NN'),
#  ('said', 'VBD'),
#  ('receive', 'JJ'),
#  ('check', 'NN'),
#  ('till', 'NN'),
#  ('xxxx', 'NNP'),
#  ('xxxx', 'NNP'),
#  ('told', 'VBD'),
#  ('believe', 'VB'),
#  ('asked', 'VBN'),
#  ('money', 'NN'),
#  ('stated', 'VBN'),
#  ('hold', 'VBP'),
#  ('payment', 'NN'),
#  ('10', 'CD'),
#  ('business', 'NN'),
#  ('days', 'NNS'),
#  ('asked', 'VBD'),
#  ('simply', 'RB'),
#  ('said', 'VBD'),
#  ('policy', 'NN'),
#  ('asked', 'VBN'),
#  ('would', 'MD'),
#  ('receive', 'VB'),
#  ('interest', 'NN'),
#  ('money', 'NN'),
#  ('stated', 'VBN'),
#  ('believe', 'VBP'),
#  ('citizens', 'NNS'),
#  ('bank', 'NN'),
#  ('deliberately', 'RB'),
#  ('delaying', 'VBG'),
#  ('posting', 'VBG'),
#  ('payment', 'NN'),
#  ('return', 'VB'),
#  ('consumer', 'NN'),
#  ('money', 'NN'),
#  ('make', 'VBP'),
#  ('additional', 'JJ'),
#  ('interest', 'NN'),
#  ('bank', 'NN'),
#  ('illegal', 'JJ'),
#  ('hurt', 'JJ'),
#  ('consumer', 'NN'),
#  ('ethical', 'JJ'),
#  ('amount', 'NN'),
#  ('money', 'NN'),
#  ('lost', 'VBN'),
#  ('minimal', 'JJ'),
#  ('thousands', 'NNS'),
#  ('car', 'NN'),
#  ('loans', 'NNS'),
#  ('month', 'NN'),
#  ('additional', 'JJ'),
#  ('interest', 'NN'),
#  ('earned', 'VBN'),
#  ('could', 'MD'),
#  ('staggering', 'VB'),
#  ('still', 'RB'),
#  ('another', 'DT'),
#  ('car', 'NN'),
#  ('loan', 'NN'),
#  ('citizens', 'NNS'),
#  ('bank', 'NN'),
#  ('afraid', 'JJ'),
#  ('trade', 'NN'),
#  ('car', 'NN'),
#  ('another', 'DT'),
#  ('year', 'NN'),
#  ('run', 'NN'),
#  ('problem', 'NN'),
#  ('account', 'NN'),
#  ('credit', 'NN'),
#  ('report', 'NN'),
#  ('mistaken', 'VBD'),
#  ('date', 'NN'),
#  ('mailed', 'VBN'),
#  ('debt', 'NN'),
#  ('validation', 'NN'),
#  ('letter', 'NN'),
#  ('allow', 'VBP'),
#  ('xxxx', 'NN'),
#  ('correct', 'JJ'),
#  ('information', 'NN'),
#  ('received', 'VBD'),
#  ('letter', 'NN'),
#  ('mail', 'NN'),
#  ('stating', 'VBG'),
#  ('experian', 'JJ'),
#  ('received', 'VBN'),
#  ('correspondence', 'NN'),
#  ('found', 'VBD'),
#  ('suspicious', 'JJ'),
#  ('write', 'JJ'),
#  ('experian', 'JJ'),
#  ('letter', 'NN'),
#  ('worded', 'VBD'),
#  ('imply', 'NN'),
#  ('incapable', 'JJ'),
#  ('writing', 'VBG'),
#  ('letter', 'NN'),
#  ('deeply', 'RB'),
#  ('offended', 'VBD'),
#  ('implication', 'NN'),
#  ('called', 'VBN'),
#  ('experian', 'JJ'),
#  ('figure', 'NN'),
#  ('letter', 'NN'),
#  ('suspicious', 'JJ'),
#  ('spoke', 'VBD'),
#  ('representative', 'JJ'),
#  ('incredibly', 'RB'),
#  ('unhelpful', 'JJ'),
#  ('effectively', 'RB'),
#  ('answer', 'VBP'),
#  ('questions', 'NNS'),
#  ('asked', 'VBD'),
#  ('kept', 'IN'),
#  ('ignoring', 'VBG'),
#  ('saying', 'VBG'),
#  ('regarding', 'VBG'),
#  ('offensive', 'JJ'),
#  ('letter', 'NN'),
#  ('dispute', 'NN'),
#  ('process', 'NN'),
#  ('feel', 'VB'),
#  ('representative', 'JJ'),
#  ('wanted', 'VBN'),
#  ('satisfied', 'VBD'),
#  ('still', 'RB'),
#  ('clear', 'JJ'),
#  ('received', 'VBN'),
#  ('letter', 'NN'),
#  ('typed', 'VBD'),
#  ('letter', 'NN'),
#  ('signed', 'VBN'),
#  ('letter', 'NN'),
#  ('paid', 'VBN'),
#  ('mail', 'NN'),
#  ('letter', 'NN'),
#  ('yet', 'RB'),
#  ('experian', 'JJ'),
#  ('willfully', 'RB'),
#  ('disregarded', 'VBN'),
#  ('lawful', 'JJ'),
#  ('request', 'NN'),
#  ('disgusted', 'VBD'),
#  ('entire', 'JJ'),
#  ('situation', 'NN'),
#  ('would', 'MD'),
#  ('like', 'VB'),
#  ('dispute', 'NN'),
#  ('handled', 'VBN'),
#  ('appropriately', 'RB'),
#  ('would', 'MD'),
#  ('like', 'VB'),
#  ('experian', 'JJ'),
#  ('representative', 'JJ'),
#  ('contact', 'NN'),
#  ('give', 'VB'),
#  ('real', 'JJ'),
#  ('explanation', 'NN'),
#  ('letter', 'NN'),
#  ('company', 'NN'),
#  ('refuses', 'VBZ'),
#  ('provide', 'VBP'),
#  ('verification', 'NN'),
#  ('validation', 'NN'),
#  ('debt', 'NN'),
#  ('per', 'IN'),
#  ('right', 'JJ'),
#  ('fdcpa', 'NN'),
#  ('believe', 'VBP'),
#  ('debt', 'NN'),
#  ('mine', 'NN'),
#  ('complaint', 'NN'),
#  ('regards', 'NNS'),
#  ('square', 'VBP'),
#  ('two', 'CD'),
#  ('financial', 'JJ'),
#  ('refer', 'NN'),
#  ('cfpb', 'NN'),
#  ('case', 'NN'),
#  ('number', 'NN'),
#  ('xxxx', 'NNP'),
#  ('regarding', 'VBG'),
#  ('cach', 'NN'),
#  ('l.', 'NN'),
#  ('l.', 'NN'),
#  ('c.', 'NN'),
#  ('square', 'NN'),
#  ('two', 'CD'),
#  ('financial', 'JJ'),
#  ('utilized', 'JJ'),
#  ('entire', 'JJ'),
#  ('social', 'JJ'),
#  ('security', 'NN'),
#  ('number', 'NN'),
#  ('include', 'VBP'),
#  ('date', 'NN'),
#  ('birth', 'NN'),
#  ('pfd', 'NN'),
#  ('document', 'NN'),
#  ('listed', 'VBD'),
#  ('complaint', 'JJ'),
#  ('initial', 'JJ'),
#  ('complaint', 'NN'),
#  ('cach', 'NN'),
#  ('l.', 'JJ'),
#  ('l.', 'NN'),
#  ('c.', 'NNS'),
#  ('square', 'VBP'),
#  ('two', 'CD'),
#  ('financial', 'JJ'),
#  ('breach', 'NN'),
#  ('following', 'VBG'),
#  ('1.', 'CD'),
#  ('identity', 'NN'),
#  ('theft', 'NN'),
#  ('assumption', 'NN'),
#  ('deterrence', 'NN'),
#  ('act', 'NN'),
#  ('2.', 'CD'),
#  ('privacy', 'NN'),
#  ('act', 'NN'),
#  ('xxxx', 'NNP'),
#  ('xxxx', 'NNP'),
#  ('social', 'JJ'),
#  ('security', 'NN'),
#  ('xxxx', 'VBP'),
#  ('4.', 'CD'),
#  ('xxxx', 'JJ'),
#  ('privacy', 'NN'),
#  ('act-which', 'JJ'),
#  ('carries', 'VBZ'),
#  ('maximum', 'JJ'),
#  ('xxxx', 'NNP'),
#  ('fine', 'NN'),
#  ('calendar', 'NN'),
#  ('cap', 'NN'),
#  ('year', 'NN'),
#  ('5.', 'CD'),
#  ('breach', 'NN'),
#  ('title', 'NN'),
#  ('xxxx', 'NNP'),
#  ('xxxx', 'NNP'),
#  ('xxxx', 'NNP'),
#  ('xxxx', 'NNP'),
#  ('xxxx', 'NNP'),
#  ('xxxx', 'NNP'),
#  ('xxxx', 'NNP'),
#  ('solution', 'NN'),
#  ('cach', 'NN'),
#  ('l.l.c', 'NN'),
#  ('handle', 'JJ'),
#  ('correction', 'NN'),
#  ('square', 'NN'),
#  ('two', 'CD'),
#  ('financial', 'JJ'),
#  ('two', 'CD'),
#  ('square', 'JJ'),
#  ('financial', 'JJ'),
#  ('submitted', 'VBN'),
#  ('xxxx', 'NN'),
#  ('xxxx', 'NNP'),
#  ('xxxx', 'NNP'),
#  ('subscriber', 'NNP'),
#  ('name', 'NN'),
#  ('form', 'NN'),
#  ('listed', 'VBN'),
#  ('cfpb', 'JJ'),
#  ('case', 'NN'),
#  ('xxxx', 'NNP'),
#  ('rendered', 'VBD'),
#  ('liable', 'JJ'),
#  ('matter', 'NN'),
#  ('addition', 'NN'),
#  ('account', 'NN'),
#  ('number', 'NN'),
#  ('associated', 'VBN'),
#  ('universal', 'JJ'),
#  ('data', 'NNS'),
#  ('form', 'NN'),
#  ('could', 'MD'),
#  ('use', 'VB'),
#  ('account', 'JJ'),
#  ('number', 'NN'),
#  ('instead', 'RB'),
#  ('ssn', 'JJ'),
#  ('dob', 'NN'),
#  ('xxxx', 'NNP'),
#  ('xxxx', 'NNP'),
#  ('xxxx', 'NNP'),
#  ('also', 'RB'),
#  ('includes', 'VBZ'),
#  ('removal', 'JJ'),
#  ('xxxx', 'NNP'),
#  ('xxxx', 'NNP'),
#  ('form', 'NN'),
#  ('cfpb', 'NN'),
#  ('case', 'NN'),
#  ('xxxx', 'NNP'),
#  ('listed', 'VBD'),
#  ('pdf', 'JJ'),
#  ('document', 'NN'),
#  ('attached', 'VBD'),
#  ('case', 'NN'),
#  ('number', 'NN'),
#  ('square', 'NN'),
#  ('two', 'CD'),
#  ('financial', 'JJ'),
#  ('contacted', 'VBD'),
#  ('xxxxxxxxxxxx', 'JJ'),
#  ('xxxx/xxxx/xxxx', 'NNP'),
#  ('e-mail', 'NN'),
#  ('regards', 'NNS'),
#  ('matter', 'NN'),
#  ('addition', 'NN'),
#  ('information', 'NN'),
#  ('sale', 'NN'),
#  ('distribution', 'NN'),
#  ('via', 'IN'),
#  ('fax', 'NN'),
#  ('fax-scanned', 'JJ'),
#  ('copied', 'VBN'),
#  ('stored', 'VBN'),
#  ('retrieval', 'NN'),
#  ('system', 'NN'),
#  ('recorded', 'VBD'),
#  ('transmitted', 'VBN'),
#  ('digitally', 'RB'),
#  ('electronically', 'RB'),
#  ('without', 'IN'),
#  ('expressed', 'VBN'),
#  ('written', 'VBN'),
#  ('consent', 'JJ'),
#  ('information', 'NN'),
#  ('protected', 'VBD'),
#  ('copyright', 'NN'),
#  ('publishing', 'NN'),
#  ('laws', 'NNS'),
#  ('xxxx', 'VBP'),
#  ('xxxx', 'JJ'),
#  ('xxxx', 'NNP'),
#  ('xxxx', 'NNP'),
#  ('information', 'NN'),
#  ('protected', 'VBD'),
#  ('xxxx', 'NNP'),
#  ('xxxx', 'NNP'),
#  ('xxxx', 'NNP'),
#  ('xxxx', 'NNP'),
#  ('xxxx', 'NNP'),
#  ('freedom', 'NN'),
#  ('speech', 'NN'),
#  ('xxxx', 'NNP'),
#  ('xxxx', 'NNP'),
#  ('xxxx', 'NNP'),
#  ('include', 'VBP'),
#  ('uniform', 'JJ'),
#  ('commercial', 'JJ'),
#  ('codes', 'NNS'),
#  ('xxxx', 'VBP'),
#  ('xxxx', 'NNP'),
#  ('rights', 'NNS'),
#  ('reserved', 'VBN'),
#  ('world', 'NN'),
#  ('wide', 'JJ')]

# %%
bow = [x for x in BoW if x not in custom]
from collections import Counter
d = dict(Counter(bow))
import operator
sorted_d = sorted(d.items(), key=operator.itemgetter(1), reverse=True)
print("Top 10 words:\n",sorted_d[:10])
# Out:
# Top 10 words:
#  [('xxxx', 63), ('letter', 12), ('check', 7), ('bank', 7), ('citizens', 6), ('square', 6), ('financial', 6), ('two', 6), ('information', 6), ('car', 5)]
